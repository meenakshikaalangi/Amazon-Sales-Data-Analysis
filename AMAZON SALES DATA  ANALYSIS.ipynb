# %% [markdown]
# # DATA ANALYSIS ON AMAZON SALES

# %% [markdown]
# ## <font color="blue">**TABLE OF CONTENT**</font>

# %% [markdown]
# - **Introduction**
# - **Problem Statement**
# - **Motive**
# - **Data Collection**
# - **Data Cleaning**
# - **Data Exploration**
# - **Exploratory Data Analysis**
# - **Conclusion**

# %% [markdown]
# ## <font color="blue">**INTRODUCTION**</font>

# %% [markdown]
# ### The Amazon Sales Report is based on a dataset of over 1.2 lakh transactions containing
# ### details such as order status, category, size, fulfillment type, shipping service, and revenue.
# ### Using Python libraries like Pandas, NumPy, Matplotlib, and Seaborn, the data was cleaned and
# ### analyzed to uncover customer preferences, product demand, and regional sales patterns.
# ### This study provides insights into overall sales performance and business growth opportunities.

# %% [markdown]
# ## <font color="blue">**PROBLEM STATEMENT**</font>

# %% [markdown]
# ### E-commerce platforms like Amazon generate massive volumes of raw sales data,
# ### which by itself does not provide meaningful insights. The problem is to analyze
# ### this data to evaluate sales performance across product categories, regions, and time periods.
# ### Key questions include: Which categories generate the most revenue? Which states and
# ### cities contribute most to sales? What are customer size and shipping preferences?
# ### How do B2B and B2C sales compare? The aim is to convert raw data into actionable insights for decision-making.

# %% [markdown]
# ## <font color="blue">**MOTIVE**</font>

# %% [markdown]
# ## The main motive of this project is to:
#
# - ### Identify high-performing and underperforming product categories.
#
# - ### Understand demand based on product sizes and shipping choices.
#
# - ### Compare fulfillment methods between Amazon and merchants.
#
# - ### Examine the share of B2B versus B2C orders.
#
# - ### Detect seasonal and regional sales trends.
# ### These insights can guide strategies to optimize inventory, reduce cancellations, and boost revenue growth.

# %% [markdown]
# ## <font color="blue">**DATA COLLECTION**</font>

# %%
#importing all necessary libraries
import warnings 
warnings.filterwarnings("ignore")
import pandas as pd
import matplotlib.pyplot as plt 
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv('amazon_data.csv',encoding= 'unicode_escape')

# %% [markdown]
# <p style="font-family:Arial; font-size:16px;">This is Arial text</p>

# %% [markdown]
# ## <font color="blue">**DATA EXPLORATION**</font>

# %%
df.shape
# Out:
# (128976, 21)

# %%
df.head()
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel ship-service-level  Category Size Courier Status  \
# 0   Merchant     Amazon.in           Standard   T-shirt    S     On the Way
# 1   Merchant     Amazon.in           Standard     Shirt  3XL        Shipped
# 2     Amazon     Amazon.in          Expedited     Shirt   XL        Shipped
# 3   Merchant     Amazon.in           Standard   Blazzer    L     On the Way
# 4     Amazon     Amazon.in          Expedited  Trousers  3XL        Shipped
#
#    ...  currency  Amount    ship-city   ship-state ship-postal-code  \
# ...

# %%
df.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel',
#        'ship-service-level', 'Category', 'Size', 'Courier Status', 'Qty',
#        'currency', 'Amount', 'ship-city', 'ship-state', 'ship-postal-code',
#        'ship-country', 'B2B', 'fulfilled-by', 'New', 'PendingS'],
#       dtype='object')

# %%
df.dtypes
# Out:
# index                   int64
# Order ID               object
# Date                   object
# Status                 object
# Fulfilment             object
# Sales Channel          object
# ship-service-level     object
# Category               object
# Size                   object
# Courier Status         object
# Qty                     int64
# currency               object
# Amount                float64
# ship-city              object
# ship-state             object
# ship-postal-code      float64
# ship-country           object
# B2B                      bool
# fulfilled-by           object
# New                   float64
# PendingS              float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128976 entries, 0 to 128975
# Data columns (total 21 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128976 non-null  int64
#  1   Order ID            128976 non-null  object
#  2   Date                128976 non-null  object
#  3   Status              128976 non-null  object
#  4   Fulfilment          128976 non-null  object
#  5   Sales Channel       128976 non-null  object
#  6   ship-service-level  128976 non-null  object
#  7   Category            128976 non-null  object
#  8   Size                128976 non-null  object
#  9   Courier Status      128976 non-null  object
#  10  Qty                 128976 non-null  int64
#  11  currency            121176 non-null  object
#  12  Amount              121176 non-null  float64
#  13  ship-city           128941 non-null  object
#  14  ship-state          128941 non-null  object
# ...

# %%
df.describe()
# Out:
#                index            Qty         Amount  ship-postal-code  New  \
# count  128976.000000  128976.000000  121176.000000     128941.000000  0.0
# mean    64486.130427       0.904401     648.562176     463945.677744  NaN
# std     37232.897832       0.313368     281.185041     191458.488954  NaN
# min         0.000000       0.000000       0.000000     110001.000000  NaN
# 25%     32242.750000       1.000000     449.000000     382421.000000  NaN
# 50%     64486.500000       1.000000     605.000000     500033.000000  NaN
# 75%     96730.250000       1.000000     788.000000     600024.000000  NaN
# max    128974.000000      15.000000    5584.000000     989898.000000  NaN
#
#        PendingS
# count       0.0
# mean        NaN
# std         NaN
# min         NaN
# 25%         NaN
# 50%         NaN
# 75%         NaN
# max         NaN

# %%
df.isnull().sum()
# Out:
# index                      0
# Order ID                   0
# Date                       0
# Status                     0
# Fulfilment                 0
# Sales Channel              0
# ship-service-level         0
# Category                   0
# Size                       0
# Courier Status             0
# Qty                        0
# currency                7800
# Amount                  7800
# ship-city                 35
# ship-state                35
# ship-postal-code          35
# ship-country              35
# B2B                        0
# fulfilled-by           89713
# New                   128976
# PendingS              128976
# dtype: int64

# %% [markdown]
# ## <font color="blue">**DATA CLEANING**</font>

# %%
#droping index column
df.drop('index',axis=1,inplace = True)

# %%
#drop irrilevant/blank columns
df.drop(['New','PendingS','fulfilled-by',], axis=1, inplace=True)

# %%
df.shape
# Out:
# (128976, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128976 entries, 0 to 128975
# Data columns (total 17 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Order ID            128976 non-null  object
#  1   Date                128976 non-null  object
#  2   Status              128976 non-null  object
#  3   Fulfilment          128976 non-null  object
#  4   Sales Channel       128976 non-null  object
#  5   ship-service-level  128976 non-null  object
#  6   Category            128976 non-null  object
#  7   Size                128976 non-null  object
#  8   Courier Status      128976 non-null  object
#  9   Qty                 128976 non-null  int64
#  10  currency            121176 non-null  object
#  11  Amount              121176 non-null  float64
#  12  ship-city           128941 non-null  object
#  13  ship-state          128941 non-null  object
#  14  ship-postal-code    128941 non-null  float64
# ...

# %%
#checking null values using seaborn
sns.heatmap(df.isnull(), yticklabels=False, cbar=False, cmap='viridis')
plt.show()

# %%
#droping null values
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (121143, 17)

# %%
# changing data type
df['ship-postal-code']=df['ship-postal-code'].astype('int')

# %%
#rename Columns
df.rename(columns={'Qty':'Quantity'})
# Out:
#                    Order ID      Date                        Status  \
# 0       405-8078784-5731545  04-30-22                     Cancelled
# 1       171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2       404-0687676-7273146  04-30-22                       Shipped
# 3       403-9615377-8133951  04-30-22                     Cancelled
# 4       407-1069790-7240320  04-30-22                       Shipped
# ...                     ...       ...                           ...
# 128971  406-6001380-7673107  05-31-22                       Shipped
# 128972  402-9551604-7544318  05-31-22                       Shipped
# 128973  407-9547469-3152358  05-31-22                       Shipped
# 128974  402-6184140-0545956  05-31-22                       Shipped
# 128975  408-7436540-8728312  05-31-22                       Shipped
#
#        Fulfilment Sales Channel ship-service-level  Category Size  \
# 0        Merchant     Amazon.in           Standard   T-shirt    S
# ...

# %%
#describe() method return description of the data in the DataFrame(i.e count,mean,std,
df.describe()
# Out:
#                  Qty         Amount  ship-postal-code
# count  121143.000000  121143.000000     121143.000000
# mean        0.961252     648.576874     463623.724507
# std         0.214276     281.196896     191301.588170
# min         0.000000       0.000000     110001.000000
# 25%         1.000000     449.000000     382421.000000
# 50%         1.000000     605.000000     500032.000000
# 75%         1.000000     788.000000     600020.000000
# max         8.000000    5584.000000     989898.000000

# %%
df.describe(include='object')
# Out:
#                    Order ID        Date   Status Fulfilment Sales Channel  \
# count                121143      121143   121143     121143        121143
# unique               112861          91       12          2             1
# top     171-5057375-2831560  05-02-2022  Shipped     Amazon     Amazon.in
# freq                     12        1932    77589      83629        121143
#
#        ship-service-level Category    Size Courier Status currency  ship-city  \
# count              121143   121143  121143         121143   121143     121143
# unique                  2        9      11              3        1       8697
# top             Expedited  T-shirt       M        Shipped      INR  BENGALURU
# freq                82713    47038   20965         109458   121143      10675
#
#          ship-state ship-country
# count        121143       121143
# unique           68            1
# top     MAHARASHTRA           IN
# freq          21084       121143

# %%
#use describe() for specific columns
df[['Qty','Amount']].describe()
# Out:
#                  Qty         Amount
# count  121143.000000  121143.000000
# mean        0.961252     648.576874
# std         0.214276     281.196896
# min         0.000000       0.000000
# 25%         1.000000     449.000000
# 50%         1.000000     605.000000
# 75%         1.000000     788.000000
# max         8.000000    5584.000000

# %% [markdown]
# ## <font color="blue">**EXPLORATORY DATA ANALYSIS**</font>

# %%
df.columns
# Out:
# Index(['Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel',
#        'ship-service-level', 'Category', 'Size', 'Courier Status', 'Qty',
#        'currency', 'Amount', 'ship-city', 'ship-state', 'ship-postal-code',
#        'ship-country', 'B2B'],
#       dtype='object')

# %% [markdown]
# ### 1Q) How may orders are placed per each Category?

# %%
#no of orders of each Category
plt.figure(figsize=(8, 5))
ax=sns.countplot(x='Category' ,data=df, hue='Category', palette='viridis')
plt.title('Orders per each category')
sns.set_theme(style='darkgrid')
for bars in ax.containers:
 ax.bar_label(bars)
plt.show()

# %% [markdown]
#  - From the above plot we can observe that the most orders are placed for T-shirts , shirts and
#  followed by other categories.

# %% [markdown]
# ### 2Q) Which Category Generated the most revenue

# %%
#Revenue Generated by each category
ax = df.groupby('Category', as_index=False)['Amount'].sum()

plt.figure(figsize=(9, 6)) 
plot = sns.barplot(x='Category', y='Amount', data=ax, hue='Category', palette='viridis')
plt.title('Category v/s Revenue ')

# Add value labels on top of each bar
for i in plot.containers:
    plot.bar_label(i, fmt='%.2f') 
plt.show()

# %% [markdown]
# - From the above plot we can observe that T-shirt's generated the highest revenue followed
#  by shirts and blazzer.

# %% [markdown]
# ### 3Q) Display the number of orders placed for each size.

# %%
#no of orders of each size
ax=sns.countplot(x='Size' ,data=df, hue='Size', palette='viridis')
plt.title('Orders per each Size')
for bars in ax.containers:
 ax.bar_label(bars)
plt.show()

# %% [markdown]
# -  From the above plot we can observe that there is more demand for M,L,XL sizes followed
#  by others.

# %% [markdown]
# ### 4Q) Display the shipping Status.

# %%
#Shipping Status of orders
ax=sns.countplot(data=df, x='Courier Status', hue='Courier Status', palette='viridis')
plt.title('Order status')
for bars in ax.containers:
 ax.bar_label(bars)
plt.show()

# %% [markdown]
# - From the above plot we can observe that most of the orders are shipped safely.

# %% [markdown]
# ###  5Q) What is the percentage of B2B and B2C orders

# %%
# Checking B2B Data by using pie chart
B2B_Check = df['B2B'].value_counts()
# Plot the pie chart
plt.figure(figsize=(3,3))
plt.pie(B2B_Check, labels=B2B_Check.index, autopct='%5.1f%%')
plt.show()

# %% [markdown]
# -  From the above plot we can observe that 99.3% of the orders are B2B

# %% [markdown]
# ### 6Q) What is the percentage of orders that are fulfilled by amazon and Merchant

# %%
# Fullfilment of order(amazon/merchant)
a1 = df['Fulfilment'].value_counts()
fig, ax = plt.subplots()
ax.pie(a1, labels=a1.index, autopct='%1.1f%%', radius=0.7, wedgeprops=dict(width=0.6))
plt.title('Amazon v/s Merchant')
ax.set(aspect="equal")
plt.show()

# %% [markdown]
# - From the above plot we can observe that 69% of the orders fullfilled by amazon and 31%
#  are by merchant

# %% [markdown]
# ### 7Q) Display the top 10 states with most number of orders

# %%
#Top ten states with most orders
top_10_state = df['ship-state'].value_counts().head(10)
# Create the plot
plt.figure(figsize=(6, 4))
plot = sns.countplot(data=df[df['ship-state'].isin(top_10_state.index)], x='ship-state')
# Add value labels on top of each bar
for i in plot.containers:
    plot.bar_label(i, label_type='edge')  # Adds the count on top of each bar
# Customize the plot
plt.xlabel('ship-state')
plt.ylabel('count')
plt.title('Distribution of State')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - From the above plot we can observe that Maharashtra placed most number of orders
#  followed by other states

# %% [markdown]
# ### 8Q) Display the top 10 states with highest revenue

# %%
#Top 10 states with highest revenue
ax=df.groupby('ship-state',as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False).head(10)
plt.figure(figsize=(12,4))
plt.xticks(rotation=90)
plt.title('Top 10 states with highest revenue')
plot = sns.barplot(x='ship-state', y='Amount', data=ax, palette = 'viridis')
# Add value labels on top of each bar
for i in plot.containers:
    plot.bar_label(i, fmt='%.2f') 
plt.show()

# %% [markdown]
# -  From the above plot we can observe that maharashtra generated the highest revenu
#  followed by karnataka

# %% [markdown]
# ### 9Q) Display the top 10 Cities with highest revenue

# %%
#Top 10 cities with highest revenue
ax=df.groupby('ship-city',as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False).head(10)
plt.figure(figsize=(12,4))
plt.xticks(rotation=90)
plot = sns.barplot(x='ship-city', y='Amount', data=ax, hue = 'ship-city', palette = 'viridis')

# Add value labels on top of each bar
for i in plot.containers:
    plot.bar_label(i, fmt='%.2f') 
plt.show()

# %% [markdown]
#  - From the above plot we can observe that beguluru generated highest revenue followed by
#  hyderabad

# %% [markdown]
# ### 10Q) Which Month received highest number of orders

# %%
# Convert Date column to datetime
df['Date'] = pd.to_datetime(df['Date'])

# Extract month and year from Date
df['Month-Year'] = df['Date'].dt.strftime('%Y-%m')

# Count orders by month
monthly_orders = df.groupby('Month-Year')['Order ID'].count().reset_index()

# Create the plot
plt.figure(figsize=(8, 4))
plot = sns.barplot(x='Month-Year', y='Order ID', data=monthly_orders, hue = 'Month-Year', palette = 'viridis')
plt.title('Month v/s orders')

# Add value labels on top of each bar
for i in plot.containers:
    plot.bar_label(i, label_type='edge')
plt.show()

# %% [markdown]
# -  From the above plot we can observe that april received the most number of orders.

# %% [markdown]
# ### 11Q) Which month generated the most revenue

# %%
 #Revenue generated by each month
df['Date'] = pd.to_datetime(df['Date']) # Convert Date column to datetime
df['Month-Year'] = df['Date'].dt.strftime('%Y-%m') # Extract month and year from Date
monthly_orders = df.groupby('Month-Year')['Amount'].sum().reset_index() # Count orders
 # Create the plot
plt.figure(figsize=(8, 4))
plot = sns.barplot(x='Month-Year', y='Amount', data=monthly_orders, palette = 'viridis')
plt.title('Month v/s Revenue')
 # Add value labels on top of each bar
for i in plot.containers:
    plot.bar_label(i, label_type='edge',fmt='%.2f')
plt.show()

# %% [markdown]
# -  From the above plot we can observe that april generated the highest revenue

# %% [markdown]
# ###  12Q) Display the most common shipping service level

# %%
#Most common shipping service level
plt.figure(figsize=(5, 4))
ax=sns.countplot(x='ship-service-level' ,data=df, hue = 'ship-service-level', palette = 'viridis')
plt.title('shipping servie')

for bars in ax.containers:
    ax.bar_label(bars)
plt.show()

# %% [markdown]
# - From the above plot we can observe that april received the most number of orders

# %% [markdown]
# ### 13Q) Which state has the highest cancelled orders

# %%
cancelled_by_state = df[df['Status'] == 'Cancelled']['ship-state'].value_counts().head(10)

# Create plot
plt.figure(figsize=(8, 5))
plot = sns.barplot(x=cancelled_by_state.index, y=cancelled_by_state.values, palette = 'viridis')

# Add value labels
for i in plot.containers:
    plot.bar_label(i, label_type='edge')

# Customize plot
plt.title('Top 10 States by Cancelled Orders')
plt.xlabel('State')
plt.ylabel('Number of Cancellations')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## <font color="blue">**CONCLUSION**</font>

# %% [markdown]
# ### The analysis revealed that T-shirts and shirts generated the highest sales and revenue,
# ### with sizes M, L, and XL being most popular. Maharashtra and Karnataka were the leading states
# ### in revenue, while Bengaluru topped among cities. April recorded the highest sales and revenue,
# ### showing strong seasonal demand. About 69% of orders were fulfilled by Amazon itself,
# ### and expedited shipping was the most preferred. Nearly 99% of the sales were B2B.
# ### However, Maharashtra also had the most cancellations, indicating operational challenges.
# ### Overall, the report highlights customer trends and provides insights that can support business optimization.
